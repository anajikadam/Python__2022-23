# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here

print("Data", "Science", "Mentorship", "Program",sep='-', end='-started-')
print("By", "CampusX", sep='-')
# Out:
# Data-Science-Mentorship-Program-started-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here

# (0°C × 9/5) + 32 = 32°F

cel_value = int(input("Enter Temperature in celsius : "))

far_value = (cel_value * (9/5)) + 32

print("{} Celsius is equal to {} Fahrenheit".format(cel_value, far_value))
# Out:
# Enter Temperature in celsius : 1
# 1 Celsius is equal to 33.8 Fahrenheit

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here

num_1 = int(input("Enter first number: "))

num_2 = int(input("Enter second number: "))
print("First number {} and second number is {}".format(num_1, num_2))

# num_2, num_1 = num_1, num_2   #not use special python syntax
temp = num_1
num_1 = num_2
num_2 = temp

print("After swapping First number {} and second number is {}".format(num_1, num_2))
# Out:
# Enter first number: 25
# Enter second number: 45
# First number 25 and second number is 45
# After swapping First number 45 and second number is 25

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here

x1 = int(input("Enter first Coordinate1 x1: "))
y1 = int(input("Enter first Coordinate1 y1: "))


x2 =  int(input("Enter second Coordinate2 x2: "))
y2 = int(input("Enter second Coordinate2 y2: "))

print("First Coordinate: ", (x1,x2) )
print("Second Coordinate: ", (y1,y2))


# euc_dist = ((((x2 - x1)**2) + ((y2 - y1)**2))**0.5)
euc_dist = ((x2 - x1)**2 + (y2 - y1)**2)**0.5

print("Euclidean distance between two given coordinates", euc_dist)
# Out:
# Enter first Coordinate1 x1: 3
# Enter first Coordinate1 y1: 3
# Enter second Coordinate2 x2: 6
# Enter second Coordinate2 y2: 12
# First Coordinate:  (3, 6)
# Second Coordinate:  (3, 12)
# Euclidean distance between two given coordinates 9.486832980505138

# %%
4**0.5
# Out:
# 2.0

# %%
# Import math Library
import math

p = [3]
q = [1]

# Calculate Euclidean distance
print (math.dist(p, q))

p = [3, 3]
q = [6, 12]

# Calculate Euclidean distance
print (math.dist(p, q))
# Out:
# 2.0
# 9.486832980505138

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p = int(input("Enter the Amount "))
t = int(input("Enter the Time "))
r = int(input("Enter the Rate"))

interest = (p*t*r)/100

print('simple interest is ', interest)
# Out:
# Enter the Amount 10000
# Enter the Time 2
# Enter the Rate5
# simple interest is  1000.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Function that calculates Dogs
def countDogs(Heads, Legs):
	count = 0

	count = (Legs) - 2 * (Heads)
	count = count / 2

	return count

# Driver code
if __name__ == '__main__':
	Heads = 4
	Legs = 10

	Dogs = countDogs(Heads, Legs)

	print("dogs =", Dogs)
	print("chicken =", Heads - Dogs)
# Out:
# dogs = 1.0
# chicken = 3.0

# %%
heads = int(input("Enter the total number of Heads: "))
legs = int(input("Enter the total number of legs: "))

dogs_count = (legs/2) - heads
chicken = heads - dogs_count

print('Dog->', dogs_count)
print('Chicken->', chicken)
# Out:
# Enter the total number of Heads: 8
# Enter the total number of legs: 24
# Dog-> 4.0
# Chicken-> 4.0

# %%
# 4d + 2c = 12 and d + c = 4
# 4d + 2c = L..........1
# d + c = H...........2
# eq 1 divide by 2 ..........3
# eq 3 substract 2 get dogs
# put dog value in eq 2


heads = int(input("Enter the total number of Heads: "))
legs = int(input("Enter the total number of legs: "))

count_dog_head= legs - 2 * (heads)
dogs_count = count_dog_head / 2

chicken = heads - dogs_count

print('Dog->', dogs_count)
print('Chicken->', chicken)
# Out:
# Enter the total number of Heads: 4
# Enter the total number of legs: 12
# Dog-> 2.0
# Chicken-> 2.0

# %%
# Write your code here

heads = int(input("Enter the total number of Heads: "))
legs = int(input("Enter the total number of legs: "))

count_dog_leg = legs - 2 * (heads)
dogs = count_dog_leg / 2

chicken = heads - dogs

print(dogs)
print(chicken)
# Out:
# Enter the total number of Heads: 4
# Enter the total number of legs: 12
# 2.0
# 2.0

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
n = int(input('enter the number'))
sum = 0


while n>0:
  sum = sum+ n**2
  n = n-1

print(sum)
# Out:
# enter the number100
# 338350

# %%
# Write your code here

# Hint - Thus, the sum of the squares of first n natural numbers = n(n+1)(2n+1)/6

n = int(input('enter the number'))

result = (n*(n+1)*(2*n + 1))/6
print(result)
# Out:
# enter the number100
# 338350.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Hint -: an = a + (n – 1)d

# Write your code here
first_term = int(input('enter 1st term'))
second_term = int(input('enter 2nd term'))


n = int(input('enter the value of n'))

d = second_term - first_term

an = first_term + (n-1)*d

print(an)
# Out:
# enter 1st term3
# enter 2nd term6
# enter the value of n5
# 15

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here


# Write your code here
n1 = int(input('num1'))
d1 = int(input('den1'))
n2 = int(input('num2'))
d2 = int(input('den2'))

rn = n1*d2 + n2*d1
rd = d1*d2

print('{}/{}'.format(rn,rd))
# Out:
# num11
# den17
# num27
# den29
# 58/63

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here

import math

h_t = float(input('height'))
b_t = float(input('breadth'))
l_t = float(input('length'))

h_g = float(input('height of glass'))
r_g = float(input('radius of the glass'))

vol_tank = h_t*b_t*l_t
vol_glass = 3.14*r_g*r_g*h_g

print('no of glasses',math.floor(vol_tank/vol_glass))
# Out:
# height10
# breadth19
# length10
# height of glass5
# radius of the glass2
# no of glasses 30

# %%
math.floor(6.9)
# Out:
# 6

# %%
math.ceil(6.9)
# Out:
# 7
