# %% [markdown]
# ### Class Relationships
#
# - Aggregation
# - Inheritance

# %% [markdown]
# ### Aggregation(Has-A relationship)

# %%
# Customer class has a Class Address
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.city, self.address.pin, self.address.state)


class Address:

  def __init__(self,city,pin,state):
      self.city = city
      self.pin = pin
      self.state = state


add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)
cust.print_address()
# Out:
# gurgaon 122011 haryana

# %%
# Customer class has a Class Address
# not access private attribute of own class (aggreated class)
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.__city, self.address.pin, self.address.state)


class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state


add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)
cust.print_address()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-88453b8c30f2> in <module>
#      21 add1 = Address('gurgaon',122011,'haryana')
#      22 cust = Customer('nitish','male',add1)
# ---> 23 cust.print_address()
#
# <ipython-input-4-88453b8c30f2> in print_address(self)
#       8
#       9   def print_address(self):
# ---> 10     print(self.address.__city, self.address.pin, self.address.state)
#      11
#      12
#
# AttributeError: 'Address' object has no attribute '_Customer__city'

# %%
# by using getter can access get private var
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address.get_city(), self.address.pin, self.address.state)


class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state

  def get_city(self):
    return self.__city

add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)
cust.print_address()
# Out:
# gurgaon 122011 haryana

# %%
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address._Address__city, self.address.pin, self.address.state)  # smart technique but not do in real ( self.address._Address__city )


class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state

  def get_city(self):
    return self.__city

add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)
cust.print_address()
# Out:
# gurgaon 122011 haryana

# %%
# example
class Customer:

  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    print(self.address._Address__city,self.address.pin,self.address.state)

  def edit_profile(self,new_name,new_city,new_pin,new_state):
    self.name = new_name                                    # new name can change by this method 
    self.address.edit_address(new_city,new_pin,new_state)           # for change new address call method of own class ( aggregated class )

class Address:

  def __init__(self,city,pin,state):
      self.__city = city
      self.pin = pin
      self.state = state

  def get_city(self):
    return self.__city

  def edit_address(self,new_city,new_pin,new_state):
    self.__city = new_city
    self.pin = new_pin
    self.state = new_state

add1 = Address('gurgaon',122011,'haryana')
cust = Customer('nitish','male',add1)

cust.print_address()

cust.edit_profile('ankit','mumbai',111111,'maharastra')
cust.print_address()
# method example
# what about private attribute
# Out:
# gurgaon 122011 haryana
# mumbai 111111 maharastra

# %% [markdown]
# ##### Aggregation class diagram

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Inheritance
#
# - What is inheritance
# - Example
# - What gets inherited?

# %%
# Inheritance and it's benefits

# code reusability

# programming principle : DRY Dont repeat yourself

# %%
# Example

# parent
class User:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

  def login(self):
    print('login')

# child
class Student(User):

  def __init__(self):               # method overriding, remove init constructor
    self.rollno = 100

  def enroll(self):
    print('enroll into the course')

u = User()
s = Student()

print(s.name)
s.login()
s.enroll()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-fc6fdf12f863> in <module>
#      23 s = Student()
#      24
# ---> 25 print(s.name)
#      26 s.login()
#      27 s.enroll()
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
# parent
class User:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

  def login(self):
    print('login')

# child
class Student(User):

  def enroll(self):
    print('enroll into the course')

u = User()
s = Student()

print(s.name)
s.login()
s.enroll()
# Out:
# nitish
# login
# enroll into the course

# %%
# Class diagram

# %% [markdown]
# ##### What gets inherited?
#
# - Constructor
# - Non Private Attributes
# - Non Private Methods

# %%
# constructor example

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 13)
s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# constructor example 2

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, os, ram):
        self.os = os
        self.ram = ram
        print ("Inside SmartPhone constructor")

s=SmartPhone("Android", 2)
s.brand
# Out:
# Inside SmartPhone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-fff5c9f9674f> in <module>
#      15
#      16 s=SmartPhone("Android", 2)
# ---> 17 s.brand
#
# AttributeError: 'SmartPhone' object has no attribute 'brand'

# %%
# child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
print(s.show())
s.check()  # child can't access private members of the class
# Out:
# Inside phone constructor
# Apple
# 20000
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-804b5a87002b> in <module>
#      19 print(s.brand)
#      20 print(s.show())
# ---> 21 s.check()  # child can't access private members of the class
#
# <ipython-input-3-804b5a87002b> in check(self)
#      14 class SmartPhone(Phone):
#      15     def check(self):
# ---> 16         print(self.__price)
#      17
#      18 s=SmartPhone(20000, "Apple", 13)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter
    def __show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
print(s.brand)
print(s.__show())
s.check()  # child can't access private members of the class
# Out:
# Inside phone constructor
# Apple
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-eb27a6dfdad3> in <module>
#      16 s=SmartPhone(20000, "Apple", 13)
#      17 print(s.brand)
# ---> 18 print(s.__show())
#      19 s.check()  # child can't access private members of the class
#
# AttributeError: 'SmartPhone' object has no attribute '__show'

# %%
# child can't access private members of the class

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    #getter to see what in private var, give access
    def show(self):
        print (self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000, "Apple", 13)
s.show()
# Out:
# Inside phone constructor
# 20000

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):   # getter
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")
        
son=Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
class Parent:

    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val=val

    def get_val(self):
        return self.__val
        
son=Child(100,10)
print("Parent: Num:",son.get_num())
print("Child: Val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5a17300f6fc7> in <module>
#      16
#      17 son=Child(100,10)
# ---> 18 print("Parent: Num:",son.get_num())
#      19 print("Child: Val:",son.get_val())
#
# <ipython-input-8-5a17300f6fc7> in get_num(self)
#       5
#       6     def get_num(self):
# ----> 7         return self.__num
#       8
#       9 class Child(Parent):
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A :", self.var1)
class B(A):
  
    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 100

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        self.var1 = var1
        print("class A :", self.var1)
class B(A):
  
    def display2(self,var1):
        print("class B :", self.var1)

obj=B()
obj.display1(200)
# Out:
# class A : 200

# %% [markdown]
# # Method Overriding  : same method name available to parent and child class then onle child method is executed only

# %%
# Method Overriding  : same method name available to parent and child class then onle child method is executed only
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
p = Phone(1000, "jio", 15)
p.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Inside phone constructor
# Buying a phone

# %% [markdown]
# ### Super Keyword
#
# is a way to access parent property from child class

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# using super outside the class
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# can super access parent ka data?
# using super outside the class  NOT


class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

s.super.buy()
# Out:
# Inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-4dcaa42a35ec> in <module>
#      21 s=SmartPhone(20000, "Apple", 13)
#      22
# ---> 23 s.super.buy()
#
# AttributeError: 'SmartPhone' object has no attribute 'super'

# %%
# can super access parent ka data?
# super can access attribute of parent class NO



class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-0e3fba319b79> in <module>
#      22 s=SmartPhone(20000, "Apple", 13)
#      23
# ---> 24 s.buy()
#
# <ipython-input-16-0e3fba319b79> in buy(self)
#      18         print ("Buying a smartphone")
#      19         # syntax to call parent ka buy method
# ---> 20         print(super().brand)
#      21
#      22 s=SmartPhone(20000, "Apple", 13)
#
# AttributeError: 'super' object has no attribute 'brand'

# %%
# super -> constuctor
# smart way to call both constructor

class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

class SmartPhone(Phone):
    def __init__(self, price, brand, camera, os, ram):
        print('Inside smartphone constructor')
        super().__init__( price, brand, camera )
        self.os = os
        self.ram = ram
        print ("Inside smartphone constructor")

s=SmartPhone(20000, "Samsung", 12, "Android", 2)

print(s.os)
print(s.brand)
# Out:
# Inside smartphone constructor
# Inside phone constructor
# Inside smartphone constructor
# Android
# Samsung

# %% [markdown]
# ##### Inheritance in summary
#
# - A class can inherit from another class.
#
# - Inheritance improves code reuse
#
# - Constructor, attributes, methods get inherited to the child class
#
# - The parent has no access to the child class
#
# - Private properties of parent are not accessible directly in child class
#
# - Child class can override the attributes or methods. This is called method overriding
#
# - super() is an inbuilt function which is used to invoke the parent class methods and constructor NOT attribute

# %%
class Parent:

    def __init__(self,num):
      self.__num=num

    def get_num(self):
      return self.__num

class Child(Parent):
  
    def __init__(self,num,val):
      super().__init__(num)
      self.__val=val

    def get_val(self):
      return self.__val
      
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.var=200
        
    def show(self):
        print(self.num)  # self refer to obj of Parent so can access Not private attribute
        print(self.var)

son=Child()
print(son.num)  # because it not private 
son.show()
# Out:
# 100
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %%
class Parent:
    def __init__(self):
        self.__num=100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("Child:",self.__var)

obj=Child()
obj.show()
# Out:
# Child: 10

# %% [markdown]
# ### Types of Inheritance
#
# - Single Inheritance
# - Multilevel Inheritance
# - Hierarchical Inheritance
# - Multiple Inheritance(Diamond Problem)
# - Hybrid Inheritance

# %%
# single inheritance
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# multilevel
class Product:
    def review(self):
        print ("Product customer review")

class Phone(Product):
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Product customer review

# %%
# Hierarchical
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(1000,"Apple","13px").buy()
FeaturePhone(10,"Lava","1px").buy()
# Out:
# Inside phone constructor
# Buying a phone
# Inside phone constructor
# Buying a phone

# %%
# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def review(self):
        print ("Customer review")

class SmartPhone(Phone, Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
s.review()
# Out:
# Inside phone constructor
# Buying a phone
# Customer review

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Product, Phone):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Product buy method

# %%
class A:
 pass

class B(A):
 pass

class C(A):
 pass

class D(A,B):
 pass

d = D()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-da1be1528b77> in <module>
#       8  pass
#       9
# ---> 10 class D(A,B):
#      11  pass
#      12
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases A, B

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-31-bb3659d52487> in <module>
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# <ipython-input-31-bb3659d52487> in m1(self)
#      13
#      14     def m1(self):
# ---> 15         val=self.m1()+20
#      16         return val
#      17 obj=C()
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-31-bb3659d52487> in m1(self)
#      13
#      14     def m1(self):
# ---> 15         val=self.m1()+20
#      16         return val
#      17 obj=C()
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism
#
# - Method Overriding
# - Method Overloading
# - Operator Overloading

# %%
# Method Overriding : same method name in child and parent class then execute chald class method only.
# constructor overriding  ...

# %%
# Method Overloading : same method name in one class 
# unfortunatly Method Overloading Not available in Python Programming
class Shape:

  def area(self,a):
    return 3.14*a*a

  def area(self,a,b):
    return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-701bc330d3e5> in <module>
#      11 s = Shape()
#      12
# ---> 13 print(s.area(2))
#      14 print(s.area(3,4))
#
# TypeError: area() missing 1 required positional argument: 'b'

# %%
# smart tech to run above code
class Shape:

  def area(self,a,b=0):
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %%
# Operator Overloading : same operator behave as differently for depends on different datatype as input

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
4 + 5
# Out:
# 9

# %%
[1,2,3] + [4,5]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Abstraction

# %%
from abc import ABC,abstractmethod
class BankApp(ABC):

  def database(self):
    print('connected to database')

  @abstractmethod
  def security(self):
    pass

  @abstractmethod
  def display(self):
    pass

# %%
class MobileApp(BankApp):

  def mobile_login(self):
    print('login into mobile')

  def security(self):
    print('mobile security')

  def display(self):
    print('display')

# %%
mob = MobileApp()

# %%
mob.security()
# Out:
# mobile security

# %%
obj = BankApp()    # not create obj of abstract class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0aa75fd04378> in <module>
# ----> 1 obj = BankApp()
#
# TypeError: Can't instantiate abstract class BankApp with abstract methods display, security
