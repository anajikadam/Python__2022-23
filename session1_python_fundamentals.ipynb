# %% [markdown]
# # 1. Python Output

# %%
print("Abhishek")
# Out:
# Abhishek

# %%
# Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print("Hello Anaji")
# Out:
# Hello Anaji

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(salman khan)
# Out:
#   File "<ipython-input-5-0713073d8d88>", line 1
#     print(salman khan)
#                  ^
# SyntaxError: invalid syntax

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True,sep='/')
# Out:
# Hello/1/4.5/True

# %%
 print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# # 2. Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World')
# Out:
# Hello World

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %%
# type
type([1,2,3])
# Out:
# list

# %% [markdown]
# # 3. Variables

# %%
# Static Vs Dynamic Typing
# Static Vs Dynamic Binding
# stylish declaration techniques

# %%
# C/C++
name = 'nitish'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# nitish
# 11

# %%
# Dynamic Typing
a = 5
# Static Typing
int a = 5
# Out:
#   File "<ipython-input-27-fdf0382d35d2>", line 4
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
# Dynamic Binding
a = 5
print(a)
a = 'nitish'
print(a)

# Static Binding
int a = 5
# Out:
#   File "<ipython-input-28-2b0bda04f818>", line 8
#     int a = 5
#         ^
# SyntaxError: invalid syntax

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c= 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
# Keywords - 33 keywords in python

# %%
# Identifiers
# You can't start with a digit
name1 = 'Nitish'
print(name1)
# You can use special chars -> _
_ = 'ntiish'
print(_)
# identiers can not be keyword
# Out:
# Nitish
# ntiish

# %% [markdown]
# # Temp Heading

# %% [markdown]
# # 5. User Input

# %%
# Static Vs Dynamic
input('Enter Email')
# Out:
# Enter Email
# ''

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
#print(type(fnum),type(snum))
# add the 2 variables
result = fnum + snum
# print the result
print(result)
print(type(fnum))
# Out:
# enter first number1
# enter second number3
# 4
# <class 'int'>

# %% [markdown]
# # 6. Type Conversion

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-72e5c45cdb6f> in <module>
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
#int(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %% [markdown]
# # 7. Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
# binary
x = 3.14j
print(x.imag)
# Out:
# 3.14

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
# use triple quotation for multi-line strings
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
# cant use just k need to assign a variable so assign it to None
k  # <--- this will give error
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# # 8. Operators - *go to next colab notebook for more on Operators and If-Else*

# %%
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership

# %% [markdown]
# # 9. If-Else
