# %% [markdown]
# ### Write OOP classes to handle the following scenarios:
#
# - A user can create and view 2D coordinates
# - A user can find out the distance between 2 coordinates
# - A user can find find the distance of a coordinate from origin
# - A user can check if a point lies on a given line
# - A user can find the distance between a given 2D point and a given line

# %%
class Point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

p1 = Point(0,0)
p2 = Point(5,6)

p1.euclidean_distance(p2)
# Out:
# 7.810249675906654

# %%
class Point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    return (self.x_cod**2 + self.y_cod**2)**0.5
    # return self.euclidean_distance(Point(0,0))   # class obj inside class itself

p1 = Point(0,0)
p2 = Point(5,6)

p1.euclidean_distance(p2)
p1.distance_from_origin()
# Out:
# 0.0

# %%
class Line:

  def __init__(self,A,B,C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

l1 = Line(1,1,-2)
print(l1)
# Out:
# 1x + 1y + -2 = 0

# %%
class Point:

  def __init__(self,x,y):
    self.x_cod = x
    self.y_cod = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cod,self.y_cod)

  def euclidean_distance(self,other):
    return ((self.x_cod - other.x_cod)**2 + (self.y_cod - other.y_cod)**2)**0.5

  def distance_from_origin(self):
    return (self.x_cod**2 + self.y_cod**2)**0.5
    # return self.euclidean_distance(Point(0,0))


class Line:

  def __init__(self,A,B,C):
    self.A = A
    self.B = B
    self.C = C

  def __str__(self):
    return '{}x + {}y + {} = 0'.format(self.A,self.B,self.C)

  # here line is self object
  def point_on_line(line,point):
    if line.A*point.x_cod + line.B*point.y_cod + line.C == 0:
      return "lies on the line"
    else:
      return "does not lie on the line"

  def shortest_distance(line,point):
    return abs(line.A*point.x_cod + line.B*point.y_cod + line.C) / (line.A**2 + line.B**2)**0.5

# %%
l1 = Line(1,1,-2)
p1 = Point(1,1)

# obj_name. method_name then obj_name is first input for mathod 
l1.point_on_line(p1)
# Out:
# 'lies on the line'

# %%
l1 = Line(1,1,-2)
p1 = Point(2,2)
l1.point_on_line(p1)
# Out:
# 'does not lie on the line'

# %%
l1 = Line(1,1,-2)
p1 = Point(1,10)
print(l1)
print(p1)

l1.shortest_distance(p1)
# Out:
# 1x + 1y + -2 = 0
# <1,10>
# 6.363961030678928

# %% [markdown]
# ### How objects access attributes

# %%
class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

  def greet(self):
    if self.country == 'india':
      print('Namaste',self.name)
    else:
      print('Hello',self.name)

# %%
# how to access attributes
p = Person('nitish','india')

# %%
p.name
# Out:
# 'nitish'

# %%
# how to access methods
p.greet()
# Out:
# Namaste nitish

# %%
# what if i try to access non-existent attributes
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-39388d77d830> in <module>
#       1 # what if i try to access non-existent attributes
# ----> 2 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %% [markdown]
# ### Attribute creation from outside of the class

# %%
p.gender = 'male'

# %%
p.gender
# Out:
# 'male'

# %% [markdown]
# ### Reference Variables
#
# - Reference variables hold the objects
# - We can create objects without reference variable as well
# - An object can have multiple reference variables
# - Assigning a new reference variable to an existing object does not create a new object

# %%
# object without a reference
class Person:

  def __init__(self):
    self.name = 'nitish'
    self.gender = 'male'

p = Person()
q = p

# %%
# Multiple ref
print(id(p))
print(id(q))
# Out:
# 140655538334992
# 140655538334992

# %%
# change attribute value with the help of 2nd object

# %%
print(p.name)
print(q.name)
q.name = 'ankit'
print(q.name)
print(p.name)
# Out:
# nitish
# nitish
# ankit
# ankit

# %% [markdown]
# ### Pass by reference

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print('Hi my name is',person.name,'and I am a',person.gender)

p = Person('nitish','male')
x = greet(p)      # pass class obj as input to the function
# Out:
# Hi my name is nitish and I am a male

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet():
  p1 = Person('ankit','male')
  return p1   # finction return as object

p = Person('nitish','male')
x = greet()
print(x.name)
print(x.gender)
# Out:
# ankit
# male

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  print(id(person))
  person.name = 'ankit'
  print(person.name)

p = Person('nitish','male')
print(id(p))
greet(p)
print(p.name)
# Out:
# 140655538334288
# 140655538334288
# ankit
# ankit

# %% [markdown]
# ### Object ki mutability

# %% [markdown]
# ### object of a class is mutable

# %%
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class -> function
def greet(person):
  person.name = 'ankit'
  return person

p = Person('nitish','male')
print(id(p))
p1 = greet(p)
print(id(p1))
# Out:
# 139767495048736
# 139767495048736

# %% [markdown]
# ### Encapsulation

# %%
# instance var -> python tutor
# name_input,country_input is instance variable 
# instance variable is special variable which value depends on objects
# Its change when object referance change
# every object instance var is difference



class Person:

  def __init__(self,name_input,country_input):
    self.name = name_input
    self.country = country_input

p1 = Person('nitish','india')
p2 = Person('steve','australia')

# %%
p1.name
# Out:
# 'nitish'

# %%
p2.name
# Out:
# 'steve'

# %% [markdown]
# ### what is Encapsulation

# %%
# before Encapsulation
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.balance = 0   # not private
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 140290406438224

# %%
obj.balance = "hehehehe"  # if variable is not private then it can be change from outside class

# %%
obj.create_pin()
obj.balance = "hehehehe"  # var updated
# Out:
# enter your pin1234
# enter balance1000
# pin created successfully

# %%
obj.withdraw()  # code crashed due to variable updated from outside of class
# Out:
# enter the pin1234
# enter the amount500
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-826ea677aa70> in <module>
# ----> 1 obj.withdraw()
#
# <ipython-input-13-6e1932017c4a> in withdraw(self)
#      72       amount = int(input('enter the amount'))
#      73       if amount <= self.__balance:
# ---> 74         self.balance = self.balance - amount
#      75         print('withdrawl successful.balance is',self.balance)
#      76       else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
# private attribute variable: __nameofAttribute (double __)
# also private methods : __method

# after Encapsulation

class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):            # Getter
    return self.__balance

  def set_balance(self,new_value):  # Setter
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj = Atm()
# Out:
# 139767475639632

# %%
obj.__balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-bba8213d86ad> in <module>
# ----> 1 obj.__balance
#
# AttributeError: 'Atm' object has no attribute '__balance'

# %% [markdown]
# ## https://realpython.com/python-getter-setter/

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance(1000)

# %%
obj.get_balance()
# Out:
# 1000

# %%
obj.set_balance('hehehe')
# Out:
# beta bahot maarenge

# %%
obj.withdraw()
# Out:
# enter the pin
# enter the amount500
# withdrawl successful.balance is 500

# %%
# __instancevar : _className__instanceVar
# when save instance variable is private then save in  memory like " _className__instanceVar  "

# %%
# try to change private var by outside from class in smart way

obj = Atm()
# Out:
# 139767495046240

# %%
obj.create_pin()
obj._Atm__balance = 'hehehe'
# Out:
# enter your pin1234
# enter balance1000
# pin created successfully

# %%
obj.withdraw()
# Out:
# enter the pin1234
# enter the amount400
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-826ea677aa70> in <module>
# ----> 1 obj.withdraw()
#
# <ipython-input-4-a9614e93d216> in withdraw(self)
#      75       # allow to withdraw
#      76       amount = int(input('enter the amount'))
# ---> 77       if amount <= self.__balance:
#      78         self.__balance = self.__balance - amount
#      79         print('withdrawl successful.balance is',self.__balance)
#
# TypeError: '<=' not supported between instances of 'int' and 'str'

# %% [markdown]
# ### https://stackoverflow.com/questions/70528/why-are-pythons-private-methods-not-actually-private
#
#
# ### https://www.quora.com/Why-doesnt-Python-have-private-member-variables-or-methods

# %% [markdown]
# ### Collection of objects

# %%
# list of objects
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

L = [p1,p2,p3]

print(L)
print(type(L))
print(type(L[0]))
for i in L:
  print(i.name,i.gender)
# Out:
# [<__main__.Person object at 0x7f1e1d419370>, <__main__.Person object at 0x7f1e1d419400>, <__main__.Person object at 0x7f1e1d4193a0>]
# <class 'list'>
# <class '__main__.Person'>
# nitish male
# ankit male
# ankita female

# %%
# Can we  save objects Set
class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

L = {p1,p2,p3}

print(L)
print(type(L))
for i in L:
  print(i.name,i.gender)
# Out:
# {<__main__.Person object at 0x7f1e26ac6100>, <__main__.Person object at 0x7f1e1d4194c0>, <__main__.Person object at 0x7f1e1d4192e0>}
# <class 'set'>
# ankita female
# nitish male
# ankit male

# %%
# dict of objects


class Person:

  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

p1 = Person('nitish','male')
p2 = Person('ankit','male')
p3 = Person('ankita','female')

d = {'p1':p1,'p2':p2,'p3':p3}

for i in d:
  print(d[i].name, d[i].gender)
# Out:
# nitish male
# ankit male
# ankita female

# %% [markdown]
# ### Static Variables(Vs Instance variables)

# %%
# need for static vars

# %%
class Atm:

  __counter = 1   # class var Atm.counter same as only counter in class, __counter is private

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    self.cid = Atm.__counter                   # when use stativ var like : className.staticVarName
    Atm.__counter = Atm.__counter + 1
    #self.menu()

  # utility functions                         # @staticmethod for static method to access it did not need to create object, directly call it by class name
  @staticmethod                                # the method which is not object method, class method it is so add @staticmethod decorator
  def get_counter():                          # method without self for staticmethod only
    return Atm.__counter


  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
c1 = Atm()
# Out:
# 139767474578288

# %%
c2 = Atm()
# Out:
# 139767474577904

# %%
c3 = Atm()
# Out:
# 139767474579056

# %%
c1.cid
# Out:
# 1

# %%
c2.cid
# Out:
# 2

# %% [markdown]
# # very IMP Question:
#
# - Static Var: class variable, it value is same for each class object
# - Instance Var: object var(depends on object), it is special var, different value for each object
#
# ## for example:
# ### 1. for bank app
#
# ### instance var: cust balance, cust name, pin
# ### static var : bank name, IFSC code, Unique cust ID
# # when use stativ var like : className.staticVarName
# # when use instance var like : objName.instanceVarName
#
# ### 2. for college app for student
# ### instance var : student name, roll nu, mark, class
# ### static var: clg name, unv name, student ID

# %%
# very IMP Question:

# Static Var: class variable, it value is same for each class object
# Instance Var: object var(depends on object), it is special var, different value for each object

# for example:
# 1. for bank app

# instance var: cust balance, cust name, pin
# static var : bank name, IFSC code, Unique cust ID

# 2. for college app for student
# instance var : student name, roll nu, mark, class
# static var: clg name, unv name, student ID

# %%
c3.get_counter()
# Out:
# 4

# %%
# getter for counter attribute

# for static method we not need to create object 
# directly use it with class.methodName()
# "@staticmethod"  for static method to access it did not need to create object, directly call it by class name
Atm.get_counter()  # after assign it to last var then it is add 1 in counter
# Out:
# 4

# %%
c3.cid
# Out:
# 3

# %%
Atm.counter  # because it is private
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-bc2e44b41fb4> in <module>
# ----> 1 Atm.counter
#
# AttributeError: type object 'Atm' has no attribute 'counter'

# %% [markdown]
# ### Static methods

# %% [markdown]
# ##### Points to remember about static
#
# - Static attributes are created at class level.
# - Static attributes are accessed using ClassName.
# - Static attributes are object independent. We can access them without creating instance (object) of the class in which they are defined.
# - The value stored in static attribute is shared between all instances(objects) of the class in which the static attribute is defined.

# %%
class Lion:
  __water_source="well in the circus"

  def __init__(self,name, gender):
      self.__name=name
      self.__gender=gender

  def drinks_water(self):
      print(self.__name, "drinks water from the",Lion.__water_source)

  @staticmethod
  def get_water_source():
      return Lion.__water_source

simba=Lion("Simba","Male")
simba.drinks_water()
print( "Water source of lions: ",Lion.get_water_source())
# Out:
# Simba drinks water from the well in the circus
# Water source of lions:  well in the circus
