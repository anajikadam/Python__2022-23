# %% [markdown]
# ## Points to remember
#
# - Codes asked are relatively easier in comparison to SDE roles
# - Pythonic syntax is preferred in most companies
# - Focus is on optimized code
# - Start with the simplest solution and then improve
# - A lot of questions are repeated so mugging up the approaches help
# - Build intuition using Python Tutor

# %%
# 1. Find the kth largest/smallest item from a list

L = [12,23,1,4,56,34,22,3]
k=3

L.sort(reverse=True)
print(L[k-1])
# Out:
# 23

# %%
# 2. Check if an array is sorted
L = [1,2,3,4,5]

flag = True

for i in range(0,len(L)-1):
  if L[i] > L[i+1]:
    flag = False

if flag:
  print('sorted')
else:
  print('not sorted')
# Out:
# sorted

# %%
# 3. Find Min/Max in a given array

L = [21,1,34,23,54,11,10]

max_val = L[0]

for i in L:
  if i > max_val:
    max_val = i

print(max_val)
# Out:
# 54

# %%
# 4. Find the first element to occur k times in an array

L = [1,1,2,3,4,4,5,5]

k = 2

d = {}

for i in L:
  if i in d:
    d[i] = d[i] + 1
  else:
    d[i] = 1

for i in d:
  if d[i] == k:
    print(i)
    break
# Out:
# 1

# %%
# 5. Find duplicates in an array
L = [1,1,2,3,4,4,5,5]

d = {}

for i in L:
  if i in d:
    d[i] = d[i] + 1
  else:
    d[i] = 1

for i in d:
  if d[i] > 1:
    print(i)
# Out:
# 1
# 4
# 5

# %%
# 6. Rotate array to left d items

L = [1,2,3,4,5]
rotate = 2

for i in range(rotate):
  temp = L[0]
  for j in range(0,len(L)-1):
    L[j] = L[j+1]
  L[len(L)-1] = temp

print(L)
# Out:
# [3, 4, 5, 1, 2]

# %%
# 7. Find intersection of 2 sorted arrays

a = [1,2,3,4,5,8]
b = [3,6,7,8]

for i in a:
  if i in b:
    print(i)
# Out:
# 3
# 8

# %%
a = [1,2,3,4,5,8]
b = [3,6,7,8]

i=j=0

while i<len(a) and j<len(b):
  if a[i] == b[j]:
    print(a[i])
    i+=1
    j+=1
  elif a[i] > b[j]:
    j+=1
  else:
    i+=1
# Out:
# 3
# 8

# %%
# 8. Find continous subarray with a given sum(given non-negative numbers)
# return the starting and ending index of the subarray
# return 1st subarray in case of multiple

L = [1,22,13,7,9,11,10]
S = 16

for i in range(0,len(L)):
  subarray = []
  for j in range(i,len(L)):
    subarray.append(L[j])
    if sum(subarray) == S:
      print(subarray)
# Out:
# [11, 10]

# %%
L = [1,22,13,7,9,11,10]

S = 35

d = {}
curr_sum = 0

for i in range(len(L)):
  curr_sum = curr_sum + L[i]

  if (curr_sum - S) in d:
    print(d[curr_sum - S]+1,i)
    break

  d[curr_sum] = i
# Out:
# 1 2

# %% [markdown]
# # 9. Find element with left side smaller/right side greater in an array

# %%
L = [3,1,2,5,8,7,9]

for i in range(1, len(L)-1):
  flag = True

  for j in range(0, i):
    if L[j] > L[i]:
      flag = False

  for k in range(i+1, len(L)):
    if L[k] < L[i]:
      flag = False

  if flag:
    print(L[i])
# Out:
# 5

# %%
# 9. Find element with left side smaller/right side greater in an array

# not consider first and last element

L = [3,1,2,5,8,7,9]

for i in range(1,len(L)-1):
  flag = True

  for j in range(0,i):
    if L[j] > L[i]:
      flag = False

  for k in range(i+1,len(L)): 
    if L[k] < L[i]:
      flag = False

  if flag:
    print(L[i])
# Out:
# 5

# %%
# best TC = O(n^3)
# max(list)  TC in O(n)
L = [3,1,2,5,8,7,9]

for i in range(1, len(L)-1):
  if max(L[:i]) < L[i] < min(L[i+1:]):
    # print(L)
    print(L[i])
# Out:
# 5

# %%
L = [3,1,2,5,8,7,9]

for i in range(1, len(L)-1):
  if max(L[:i]) < L[i] < min(L[i+1:]):
    print(L)
    print(L[i])

# %%
L = [3,1,2,5,8,7,9]

for i in range(1,len(L)-1):
  if max(L[:i]) < L[i] < min(L[i+1:]):
    print(L[i])
# Out:
# 5

# %%
L = [3,1,2,5,8,7,9]

max_arr = []
min_arr = []

max_val = L[0]
min_val = L[-1]

for i in L:
  if i>max_val:
    max_val = i
  max_arr.append(max_val)

for i in range(len(L)-1,-1,-1):
  if L[i] < min_val:
    min_val = L[i]
  
  min_arr.insert(0,min_val)


for i in range(1,len(L)-1):
  if max_arr[i-1] < L[i] < min_arr[i+1]:
    print(L[i])
# Out:
# 5

# %% [markdown]
# # 10. Maximum sum subarray

# %%
# 10. Maximum sum subarray

# continuous items which is subset of main array 
# which subset array has max sum
L = [-2,4,7,-1,6,-11,14,3,-1,-6]

for i in range(0, len(L)):
  subarray = []
  for j in range(i, len(L)):
    subarray.append(L[j])
    print(subarray, sum(subarray))
# Out:
# [-2] -2
# [-2, 4] 2
# [-2, 4, 7] 9
# [-2, 4, 7, -1] 8
# [-2, 4, 7, -1, 6] 14
# [-2, 4, 7, -1, 6, -11] 3
# [-2, 4, 7, -1, 6, -11, 14] 17
# [-2, 4, 7, -1, 6, -11, 14, 3] 20
# [-2, 4, 7, -1, 6, -11, 14, 3, -1] 19
# [-2, 4, 7, -1, 6, -11, 14, 3, -1, -6] 13
# [4] 4
# [4, 7] 11
# [4, 7, -1] 10
# [4, 7, -1, 6] 16
# [4, 7, -1, 6, -11] 5
# [4, 7, -1, 6, -11, 14] 19
# [4, 7, -1, 6, -11, 14, 3] 22
# [4, 7, -1, 6, -11, 14, 3, -1] 21
# [4, 7, -1, 6, -11, 14, 3, -1, -6] 15
# [7] 7
# [7, -1] 6
# [7, -1, 6] 12
# [7, -1, 6, -11] 1
# [7, -1, 6, -11, 14] 15
# [7, -1, 6, -11, 14, 3] 18
# [7, -1, 6, -11, 14, 3, -1] 17
# [7, -1, 6, -11, 14, 3, -1, -6] 11
# [-1] -1
# [-1, 6] 5
# [-1, 6, -11] -6
# [-1, 6, -11, 14] 8
# [-1, 6, -11, 14, 3] 11
# [-1, 6, -11, 14, 3, -1] 10
# [-1, 6, -11, 14, 3, -1, -6] 4
# [6] 6
# [6, -11] -5
# [6, -11, 14] 9
# [6, -11, 14, 3] 12
# [6, -11, 14, 3, -1] 11
# [6, -11, 14, 3, -1, -6] 5
# [-11] -11
# [-11, 14] 3
# [-11, 14, 3] 6
# [-11, 14, 3, -1] 5
# [-11, 14, 3, -1, -6] -1
# [14] 14
# [14, 3] 17
# [14, 3, -1] 16
# [14, 3, -1, -6] 10
# [3] 3
# [3, -1] 2
# [3, -1, -6] -4
# [-1] -1
# [-1, -6] -7
# [-6] -6

# %%
L = [-2,4,7,-1,6,-11,14,3,-1,-6]


di = {}
for i in range(0, len(L)):
  subarray = []
  for j in range(i, len(L)):
    subarray.append(L[j])
    # print(subarray)
    di[sum(subarray)] = subarray


print(di)
print(di.keys())
print(max(di.keys()))
mx = max(di.keys())
print(di[mx])

# Problem : if may be sum of subarray is same then there is replace second subarray to first array in dict
# so use list
# Out:
# {-2: [-2, 4, 7, -1, 6, -11, 14, 3, -1, -6], 2: [3, -1, -6], 9: [6, -11, 14, 3, -1, -6], 8: [-1, 6, -11, 14, 3, -1, -6], 14: [14, 3, -1, -6], 3: [3, -1, -6], 17: [14, 3, -1, -6], 20: [-2, 4, 7, -1, 6, -11, 14, 3, -1, -6], 19: [4, 7, -1, 6, -11, 14, 3, -1, -6], 13: [-2, 4, 7, -1, 6, -11, 14, 3, -1, -6], 4: [-1, 6, -11, 14, 3, -1, -6], 11: [6, -11, 14, 3, -1, -6], 10: [14, 3, -1, -6], 16: [14, 3, -1, -6], 5: [-11, 14, 3, -1, -6], 22: [4, 7, -1, 6, -11, 14, 3, -1, -6], 21: [4, 7, -1, 6, -11, 14, 3, -1, -6], 15: [7, -1, 6, -11, 14, 3, -1, -6], 7: [7, -1, 6, -11, 14, 3, -1, -6], 6: [-11, 14, 3, -1, -6], 12: [6, -11, 14, 3, -1, -6], 1: [7, -1, 6, -11, 14, 3, -1, -6], 18: [7, -1, 6, -11, 14, 3, -1, -6], -1: [-1, -6], -6: [-6], -5: [6, -11, 14, 3, -1, -6], -11: [-11, 14, 3, -1, -6], -4: [3, -1, -6], -7: [-1, -6]}
# dict_keys([-2, 2, 9, 8, 14, 3, 17, 20, 19, 13, 4, 11, 10, 16, 5, 22, 21, 15, 7, 6, 12, 1, 18, -1, -6, -5, -11, -4, -7])
# 22
# [4, 7, -1, 6, -11, 14, 3, -1, -6]

# %%
L = [-2,4,7,-1,6,-11,14,3,-1,-6]

l1 = []
l2 = []
for i in range(0, len(L)):
  subarray = []
  for j in range(i, len(L)):
    subarray.append(L[j])
    # print(subarray)
    l1.append(sum(subarray))
    l2.append(subarray)

import pandas as pd
df = pd.DataFrame({'sum':l1,'subarray':l2})
# df.sort_values(by='sum', ascending=False)
df[df['sum'] == max(df['sum'])]
# Out:
#     sum                           subarray
# 16   22  [4, 7, -1, 6, -11, 14, 3, -1, -6]

# %%
# 10. Maximum sum subarray
# TC = O(n^2)


L = [-2,4,7,-1,6,-11,14,3,-1,-6]

d = {}

for i in range(0,len(L)):
  subarray = []
  for j in range(i,len(L)):
    subarray.append(L[j])
    d[sum(subarray)] = subarray

max_val = max(d.keys())

for i in d:
  if i == max_val:
    print(d[i])
# Out:
# [4, 7, -1, 6, -11, 14, 3, -1, -6]

# %%
L = [-2,4,7,-1,6,-11,14,3,-1,-6]
curr_sum = 0
cseq = []
best_sum = 0
best_seq = []

for i in L:
  if i + curr_sum > i:
    curr_sum += i
    cseq.append(i)
  else:
    curr_sum = i
    cseq.clear()
    cseq.append(i)

  if curr_sum > best_sum:
    best_sum = curr_sum
    best_seq = cseq

print(best_sum, best_seq)
# Out:
# 22 [4, 7, -1, 6, -11, 14, 3, -1, -6]

# %%
# reduce Time complexity  : 00:35:00

# TC O(n)
# O(n) is always better than O(n^2)

L = [-2,4,7,-1,6,-11,14,3,-1,-6]


curr_sum = 0
curr_seq = []
best_sum = L[0]
best_seq = []

for i in L:
  if i + curr_sum > i:
    curr_sum = curr_sum + i
    curr_seq.append(i)
  else:
    curr_sum = i
    curr_seq.clear()
    curr_seq.append(i)

  if curr_sum > best_sum:
    best_sum = curr_sum
    best_seq = curr_seq

print(best_sum,best_seq)
# Out:
# 22 [4, 7, -1, 6, -11, 14, 3, -1, -6]

# %%
import sys # biggest posible int
sys.maxsize
# Out:
# 9223372036854775807

# %%
import sys # smallest posible int
-sys.maxsize-1
# Out:
# -9223372036854775808

# %%
L = [-2,4,7,-1,6,-11,14,3,-1,-6]


curr_sum = 0
curr_seq = []
best_sum = -sys.maxsize-1
best_seq = []

for i in L:
  if i + curr_sum > i:
    curr_sum = curr_sum + i
    curr_seq.append(i)
  else:
    curr_sum = i
    curr_seq.clear()
    curr_seq.append(i)

  if curr_sum > best_sum:
    best_sum = curr_sum
    best_seq = curr_seq

print(best_sum,best_seq)
# Out:
# 22 [4, 7, -1, 6, -11, 14, 3, -1, -6]

# %%
# 11. Sort arrays with items 1 and 0

# %%
# 12. Move all -ve numbers to the end

# %%
# 13. Maximum Product Subarray

# %%
# 14. Find union of 2 arrays

# %%
# 15. Find Pythagorean triplets in an array
